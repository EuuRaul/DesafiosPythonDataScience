# %%
#QUESTÃO 1 - Análise Númerica
print("Que tal a gente fazer um teste de números")
numero1 = int(input("Forneça um número: "))
numero2 = int(input("Agora forneça outro número: "))
if numero1 > numero2:
  print(f"O numero maior é o número: {numero1}")
elif numero1 < numero2:
  print(f"O numero maior é o número: {numero2}")
else:
  print("São números iguais")

#QUESTÃO 2 - Percentual da Empresa
print("\nSua empresa começou a um mês e o percentual dela era de 0%")
percentualempresa = float(input("Me diga o percentual atual (em apenas números positivos ou negativos) que a empresa adquiriu: "))
if percentualempresa > 0:
  print("Sua empresa teve uma porcentagem positiva")
else:
  print("Sua empresa teve uma porcentagem negativa")

#QUESTÃO 3 - Identificação de Consoante ou Letra
letra = input("\nMe forneça uma letra: ")
letra = letra.strip().lower()
VOGAIS = "a", "e", "i", "o", "u"

if letra in VOGAIS:
  print("Você forneceu uma vogal")
else:
  print("Você forneceu uma consoante")

#QUESTÃO 4 - Valores de Carro
print("\nEstamos em um leilão de carros, e você vai decidir os 3 valores oferecidos")
valor1 = float(input("A primeira oferta oferecida foi: "))
valor2 = float(input("A segunda oferta oferecida foi: "))
valor3 = float(input("E por fim a terceira oferta foi: "))

if valor1 > valor2 > valor3:
  print(f"O valor mais caro foi {valor1} e o valor mais barato oferecido foi {valor3}")
elif valor1 > valor3 > valor2:
  print(f"O valor mais caro foi {valor1} e o valor mais barato oferecido foi {valor2}")
elif valor2 > valor1 > valor3:
  print(f"O valor mais caro foi {valor2} e o valor mais barato oferecido foi {valor3}")
elif valor2 > valor3 > valor1:
  print(f"O valor mais caro foi {valor2} e o valor mais barato oferecido foi {valor1}")
elif valor3 > valor2 > valor1:
  print(f"O valor mais caro foi {valor3} e o valor mais barato oferecido foi {valor1}")
else:
  print(f"O valor mais caro foi {valor3} e o valor mais barato oferecido foi {valor2}")

#QUESTÃO 5 - Qual o valor mais barato?
print("\nVamos imaginar que tem 3 produtos, qual será o mais barato?")
preço1 = int(input("Me diga o preço do 1 produto: "))
preço2 = int(input("Me diga o preço do 2 produto: "))
preço3 = int(input("Me diga o preço do 3 produto: "))
preco1_e_preco2 = preço1 = preço2
preco1_e_preco3 = preço1 = preço3

if Preços12 < preço3:
  print(f"O produto mais barato é o do preço: {preço3}")
elif Preços13 < preço2:
  print(f"O produto mais barato é o do preço: {preço2}")
else:
  print(f"O produto mais barato é o do preço: {preço1}")

#QUESTÃO 6 - Ordem decrescente números
print("\nVamos usar os números utilizados lá no começo para colocar em ordem descrescente")
numero3 = int(input("No entanto vou precisar de mais um número: "))

if numero1 < numero2 < numero3:
  print(f"A ordem decrescente dos números selecionados são: {numero3}, {numero2} e {numero1}") #3 é maior que 2 e 1
elif numero1 < numero3 < numero2:
  print(f"A ordem decrescente dos números selecionados são: {numero2}, {numero3} e {numero1}") #2 é maior que 3 e 1
elif numero2 < numero1 < numero3:
  print(f"A ordem decrescente dos números selecionados são: {numero3}, {numero1} e {numero2}") #3 é maior que um 1 e 2
elif numero2 < numero3 < numero1:
  print(f"A ordem decrescente dos números selecionados são: {numero1}, {numero3} e {numero2}") #1 é maior que 3 e 2
elif numero3 < numero1 < numero2:
  print(f"A ordem decrescente dos números selecionados são: {numero2}, {numero1} e {numero3}") #2 é um numero maior que 1 e 3
else:
  print(f"A ordem decrescente dos números selecionados são: {numero1}, {numero2} e {numero3}") #1 é maior que 2 e 3

#QUESTÃO 7 - Turnos e Mensagens
turno = input("\nQual turno você estuda? (manhã, tarde ou noite) ")
turno = turno.strip().lower()

if turno == "manhã":
  print("Bom Dia!")
elif turno == "tarde":
  print("Boa Tarde!")
elif turno == "noite":
  print("Boa Noite!")
else:
  print("Valor Inválido")

#QUESTÃO 8 - Par ou Impar?
print("\nO número oferecido por vocês é par ou impar em? Vamos descobrir")
numero4 = int(input("Me diga novamente um número: "))
if numero4 % 2 == 0:
  print("Seu número é par")
else:
  print("Seu número é impar")

#QUESTÃO 9 - Inteiro ou Decimal?
print("\nVamos aproveitar o número anterior para saber se é Inteiro ou Decimal")
tipoNumero = type(numero4)
if tipoNumero == float:
  print("Número Decimal")
else:
  print("Número Inteiro")
# Out:
# Que tal a gente fazer um teste de números
# Forneça um número: 100
# Agora forneça outro número: 100
# O numero maior é o número: 100
#
# Sua empresa começou a um mês e o percentual dela era de 0%
# Me diga o percentual atual (em apenas números positivos ou negativos) que a empresa adquiriu: 100
# Sua empresa teve uma porcentagem positiva
#
# Me forneça uma letra: U
# Você forneceu uma vogal
#
# Estamos em um leilão de carros, e você vai decidir os 3 valores oferecidos
# A primeira oferta oferecida foi: 100
# A segunda oferta oferecida foi: 100
# E por fim a terceira oferta foi: 100
# O valor mais caro foi 100.0 e o valor mais barato oferecido foi 100.0
#
# Vamos imaginar que tem 3 produtos, qual será o mais barato?
# Me diga o preço do 1 produto: 100
# Me diga o preço do 2 produto: 100
# Me diga o preço do 3 produto: 100
# O produto mais barato é o do preço: 100
#
# Vamos usar os números utilizados lá no começo para colocar em ordem descrescente
# ...
